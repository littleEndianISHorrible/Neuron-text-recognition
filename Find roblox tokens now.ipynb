# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import threading
import random
import requests

# Define your operation function
items = [f"{i:08d}" for i in range(1, 10000000000)]
num_threads = 500
def append_to_file(data, file_path=r"C:\Users\maxik\Documents\GitHub\Nuron-text-recognition\fileROBLOXtokens.txt"):
    try:
        open(file_path, "r")
    except:
        open(file_path, "x")
    try:
        with open(file_path, "a") as file:
            file.write(data + "\n")
        print(f"Data appended to {file_path}")
    except Exception as e:
        print(f"Error appending data to {file_path}: {e}")
def is_valid_url(url):
    try:
        response = requests.head(url)
        return response.status_code == 200
    except requests.ConnectionError:
        return False

def my_operation(item):
    try:
        # Your operation logic here
        url_to_check = "https://www.roblox.com/games/" + item + "/Murder-Mystery-2"
        if is_valid_url(url_to_check):
            append_to_file(item)
        else:
            print(f"Error appending data ")
            append_to_file(item)
    except Exception as e:
        pass
# Function to check if a URL is valid (returns true if status code is 200)

# Number of threads (adjust as needed)


# List of items (replace with your actual data)
  # Example: 1 to 99,999,999

# Split the items among threads
split_size = len(items) // num_threads

# Create and start threads
threads = []
for i in range(num_threads):
    start = i * split_size
    end = (i + 1) * split_size if i < num_threads - 1 else len(items)
    thread = threading.Thread(target=my_operation, args=(items[start:end],))
    threads.append(thread)
    #print("starting threads")
    thread.start()
    print(threads)

# Wait for all threads to finish
for thread in threads:
    thread.join()

print("All threads completed.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 6
#       3 import requests
#       5 # Define your operation function
# ----> 6 items = [f"{i:08d}" for i in range(1, 10000000000)]
#       7 num_threads = 500
#       8 def append_to_file(data, file_path=r"C:\Users\maxik\Documents\GitHub\Nuron-text-recognition\fileROBLOXtokens.txt"):
#
# KeyboardInterrupt:

# %%
import threading
import random
import requests

# Define your operation function
items = [f"{i:08d}" for i in range(1, 10000000)]
num_threads = 100

def append_to_file(data, file_path=r"C:\Users\maxik\Documents\GitHub\Nuron-text-recognition\fileROBLOXtokens.txt"):
    try:
        open(file_path, "r")
    except:
        open(file_path, "x")
    try:
        with open(file_path, "a") as file:
            file.write(data + "\n")
        print(f"Data appended to {file_path}")
    except Exception as e:
        print(f"Error appending data to {file_path}: {e}")

def is_valid_url(url):
    try:
        response = requests.head(url)
        return response.status_code == 200
    except requests.ConnectionError:
        return False

def my_operation(item):
    try:
        # Your operation logic here
        url_to_check = "https://www.roblox.com/games/" + item + "/Murder-Mystery-2"
        if is_valid_url(url_to_check):
            append_to_file(item)
        else:
            print(f"Error appending data for item {item}")
            append_to_file(item)
    except Exception as e:
        pass

# Split the items among threads
split_size = len(items) // num_threads

# Create and start threads
threads = []
for i in range(num_threads):
    start = i * split_size
    end = (i + 1) * split_size if i < num_threads - 1 else len(items)
    thread = threading.Thread(target=my_operation, args=(items[start:end],))
    threads.append(thread)
    thread.start()

# Wait for all threads to finish
for thread in threads:
    thread.join()

print("All threads completed.")
# Out:
# All threads completed.

# %%
import threading
import random
import requests
import tkinter as tk
from tkinter import ttk

# Define your operation function
items = [f"{i:08d}" for i in range(1, 10000000)]
num_threads = 100

def append_to_file(data, file_path=r"C:\Users\maxik\Documents\GitHub\Nuron-text-recognition\fileROBLOXtokens.txt"):
    try:
        open(file_path, "r")
    except:
        open(file_path, "x")
    try:
        with open(file_path, "a") as file:
            file.write(data + "\n")
        print(f"Data appended to {file_path}")
    except Exception as e:
        print(f"Error appending data to {file_path}: {e}")

def is_valid_url(url):
    try:
        response = requests.head(url)
        return response.status_code == 200
    except requests.ConnectionError:
        return False

def my_operation(item, progress_var):
    try:
        # Your operation logic here
        url_to_check = "https://www.roblox.com/games/" + item + "/Murder-Mystery-2"
        if is_valid_url(url_to_check):
            append_to_file(item)
        else:
            print(f"Error appending data for item {item}")
            append_to_file(item)

        # Update progress
        progress_var.set(progress_var.get() + 1)
    except Exception as e:
        pass

def start_threads():
    # Split the items among threads
    split_size = len(items) // num_threads

    # Create and start threads
    threads = []
    for i in range(num_threads):
        start = i * split_size
        end = (i + 1) * split_size if i < num_threads - 1 else len(items)
        thread = threading.Thread(target=my_operation, args=(items[start:end], progress_var))
        threads.append(thread)
        thread.start()

    # Wait for all threads to finish
    for thread in threads:
        thread.join()

    print("All threads completed.")

# Create the main GUI window
root = tk.Tk()
root.title("Threaded Operation Progress")

# Create a progress bar
progress_var = tk.IntVar()
progress_bar = ttk.Progressbar(root, variable=progress_var, maximum=len(items))
progress_bar.pack(pady=10)

# Start button
start_button = ttk.Button(root, text="Start Operation", command=start_threads)
start_button.pack()

root.mainloop()
# Out:
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.
# All threads completed.

# %%
import threading
import random
import requests
import tkinter as tk
from tkinter import ttk
root = tk.Tk()
root.title("Threaded Operation Progress")
# Define your operation function
items = [f"{i:08d}" for i in range(1, 100000000)]
num_threads = 100

def append_to_file(data, file_path=r"C:\Users\maxik\Documents\GitHub\Nuron-text-recognition\fileROBLOXtokens.txt"):
    try:
        open(file_path, "r")
    except:
        open(file_path, "x")
    try:
        with open(file_path, "a") as file:
            file.write(data + "\n")
        print(f"Data appended to {file_path}")
    except Exception as e:
        print(f"Error appending data to {file_path}: {e}")

def is_valid_url(url):
    try:
        response = requests.head(url)
        return response.status_code == 200
    except requests.ConnectionError:
        return False

def my_operation(item, progress_var):
    try:
        # Your operation logic here
        url_to_check = "https://www.roblox.com/games/" + item + "/Murder-Mystery-2"
        if is_valid_url(url_to_check):
            append_to_file(item)
        else:
            print(f"Error appending data for item {item}")
            append_to_file(item)

        # Update progress
        progress_var.set(progress_var.get() + 1)
    except Exception as e:
        pass

def start_threads():
    # Split the items among threads
    split_size = len(items) // num_threads

    # Create and start threads
    threads = []
    for i in range(num_threads):
        start = i * split_size
        end = (i + 1) * split_size if i < num_threads - 1 else len(items)
        thread = threading.Thread(target=my_operation, args=(items[start:end], progress_var))
        threads.append(thread)
        thread.start()

    # Wait for all threads to finish
    for thread in threads:
        thread.join()

    print("All threads completed.")

# Create the main GUI window


# Create a progress bar with green color
style = ttk.Style()
style.theme_use("default")
style.configure("green.Horizontal.TProgressbar", background="green")
progress_var = tk.IntVar()
progress_bar = ttk.Progressbar(root, variable=progress_var, maximum=len(items), style="green.Horizontal.TProgressbar")
progress_bar.pack(pady=10)

# Start button
start_button = ttk.Button(root, text="Start Operation", command=start_threads)
start_button.pack()

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 9
#       7 root.title("Threaded Operation Progress")
#       8 # Define your operation function
# ----> 9 items = [f"{i:08d}" for i in range(1, 100000000)]
#      10 num_threads = 100
#      12 def append_to_file(data, file_path=r"C:\Users\maxik\Documents\GitHub\Nuron-text-recognition\fileROBLOXtokens.txt"):
#
# KeyboardInterrupt:

# %%
import threading
import random
import requests
import tkinter as tk
from tkinter import ttk
import sys
# Define your operation function
#items = [f"{i:08d}" for i in range(1, 1000000000000)]
num_threads = 100

def append_to_file(data, file_path=r"C:\Users\maxik\Documents\GitHub\Nuron-text-recognition\fileROBLOXtokens.txt"):
    try:
        open(file_path, "r")
    except:
        open(file_path, "x")
    try:
        with open(file_path, "a") as file:
            file.write(data + "\n")
        print(f"Data appended to {file_path}")
    except Exception as e:
        print(f"Error appending data to {file_path}: {e}")

def is_valid_url(url):
    try:
        response = requests.head(url)
        return response.status_code == 200
    except requests.ConnectionError:
        return False

def my_operation(item, progress_var, progress_label):
    try:
        # Your operation logic here
        url_to_check = "https://www.roblox.com/games/" + item + "/Murder-Mystery-2"
        if is_valid_url(url_to_check):
            append_to_file(item)
        else:
            print(f"Error appending data for item {item}")
            append_to_file(item)

        # Update progress
        progress_var.set(progress_var.get() + 1)
        progress_label.config(text=f"Progress: {progress_var.get()} / {len(items)}")
    except Exception as e:
        pass

def start_threads():
    total_items = 1000000000000
    num_threads = 100
    items_per_thread = total_items // num_threads

    # Create and start threads
    threads = []
    for i in range(num_threads):
        start = i * items_per_thread + 1
        end = (i + 1) * items_per_thread if i < num_threads - 1 else total_items
        thread = threading.Thread(target=my_operation, args=(start, end, progress_var))
        threads.append(thread)
        thread.start()

    # Wait for all threads to finish
    for thread in threads:
        thread.join()

    print("All threads completed.")
    sys.exit()
sys.stdout = open("thread_output.txt", "w")
start_threads()
# Create the main GUI window

# root = tk.Tk()
# root.title("Threaded Operation Progress")
# items = [f"{i:08d}" for i in range(1, 1000000000000)]
# # Create a progress bar with green color
# style = ttk.Style()
# style.theme_use("default")
# style.configure("green.Horizontal.TProgressbar", background="green")
# progress_var = tk.IntVar()
# progress_bar = ttk.Progressbar(root, variable=progress_var, maximum=len(items), style="green.Horizontal.TProgressbar")
# progress_bar.pack(pady=10)

# # Create a label to display progress
# progress_label = tk.Label(root, text="Progress: 0 / " + str(len(items)))
# progress_label.pack()

# # Start button
# start_button = ttk.Button(root, text="Start Operation", command=start_threads)
# start_button.pack()

# root.mainloop()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
import threading
import random
import requests
import tkinter as tk
from tkinter import ttk
import sys
# Define your operation function
#items = [f"{i:08d}" for i in range(1, 1000000000000)]
num_threads = 100

def append_to_file(data, file_path=r"C:\Users\maxik\Documents\GitHub\Nuron-text-recognition\fileROBLOXtokens.txt"):
    try:
        open(file_path, "r")
    except:
        open(file_path, "x")
    try:
        with open(file_path, "a") as file:
            file.write(data + "\n")
        print(f"Data appended to {file_path}")
    except Exception as e:
        print(f"Error appending data to {file_path}: {e}")

def is_valid_url(url):
    try:
        response = requests.head(url)
        return response.status_code == 200
    except requests.ConnectionError:
        return False

def my_operation(item, progress_var, progress_label):
    try:
        # Your operation logic here
        url_to_check = "https://www.roblox.com/games/" + item + "/Murder-Mystery-2"
        if is_valid_url(url_to_check):
            append_to_file(item)
        else:
            print(f"Error appending data for item {item}")
            append_to_file(item)

        # Update progress
        progress_var.set(progress_var.get() + 1)
        progress_label.config(text=f"Progress: {progress_var.get()} / {len(items)}")
    except Exception as e:
        pass

def start_threads():
    total_items = 1000000000000
    num_threads = 100
    items_per_thread = total_items // num_threads

    # Create and start threads
    threads = []
    for i in range(num_threads):
        start = i * items_per_thread + 1
        end = (i + 1) * items_per_thread if i < num_threads - 1 else total_items
        thread = threading.Thread(target=my_operation, args=(start, end, progress_var))
        threads.append(thread)
        thread.start()

    # Wait for all threads to finish
    for thread in threads:
        thread.join()

    print("All threads completed.")
    sys.exit()
sys.stdout = open("thread_output.txt", "w")
start_threads()
# Create the main GUI window

# root = tk.Tk()
# root.title("Threaded Operation Progress")
# items = [f"{i:08d}" for i in range(1, 1000000000000)]
# # Create a progress bar with green color
# style = ttk.Style()
# style.theme_use("default")
# style.configure("green.Horizontal.TProgressbar", background="green")
# progress_var = tk.IntVar()
# progress_bar = ttk.Progressbar(root, variable=progress_var, maximum=len(items), style="green.Horizontal.TProgressbar")
# progress_bar.pack(pady=10)

# # Create a label to display progress
# progress_label = tk.Label(root, text="Progress: 0 / " + str(len(items)))
# progress_label.pack()

# # Start button
# start_button = ttk.Button(root, text="Start Operation", command=start_threads)
# start_button.pack()

# root.mainloop()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
import threading
import requests

def append_to_file(data, file_path="fileROBLOXtokens.txt"):
    try:
        with open(file_path, "a") as file:
            file.write(f"{str(data)}" + "\n")
        print(f"Data appended to {file_path}")
    except Exception as e:
        print(f"Error appending data to {file_path}: {e}")

def is_valid_url(url):
    try:
        response = requests.head(url)
        return response.status_code == 200
    except requests.ConnectionError:
        return False

def my_operation(item, progress_var, progress_label):
    try:
        url_to_check = f"https://www.roblox.com/games/{item}/Murder-Mystery-2"
        if is_valid_url(url_to_check):
            append_to_file(item)
        else:
            print(f"Error appending data for item {item}")
        # progress_var.set(progress_var.get() + 1)
        # progress_label.config(text=f"Progress: {progress_var.get()} / {len(items)}")
    except Exception as e:
        pass
    progress_var.set(progress_var.get() + 1)
progress_var = (0)
def start_threads():
    total_items = 1000000000
    num_threads = 100
    items_per_thread = total_items // num_threads
    # Initialize progress variables (you need to set these values)
    # Create and start threads
    threads = []
    for i in range(num_threads):
        start = i * items_per_thread + 1
        end = (i + 1) * items_per_thread if i < num_threads - 1 else total_items
        thread = threading.Thread(target=my_operation, args=(start, end, progress_var))
        threads.append(thread)
        thread.start()
    # Wait for all threads to finish
    for thread in threads:
        thread.join()
        print(thread)
    print("All threads completed.")

# Call the start_threads function
start_threads()
# Out:
# Exception in thread Thread-226 (my_operation):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1008.0_x64__qbz5n2kfra8p0\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\maxik\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ipykernel\ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1008.0_x64__qbz5n2kfra8p0\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\maxik\AppData\Local\Temp\ipykernel_25596\1013801203.py", line 30, in my_operation
# AttributeError: 'int' object has no attribute 'set'
# Exception in thread Thread-289 (my_operation):
# Traceback (most recent call last):
# ...

# %%
import threading
import requests

# Global variable to keep track of the count
count_lock = threading.Lock()
total_count = 0

def append_to_file(data, file_path="fileROBLOXtokens.txt"):
    try:
        with open(file_path, "a") as file:
            file.write(f"{str(data)}" + "\n")
        print(f"Data appended to {file_path}")
    except Exception as e:
        print(f"Error appending data to {file_path}: {e}")

def is_valid_url(url):
    try:
        response = requests.head(url)
        return response.status_code == 200
    except requests.ConnectionError:
        return False

def my_operation(start, end, progress_var):
    global total_count
    try:
        for item in range(start, end + 1):
            url_to_check = f"https://www.roblox.com/games/{item}/Murder-Mystery-2"
            if is_valid_url(url_to_check):
                append_to_file(item)
                with count_lock:
                    total_count += 1
            else:
                print(f"Error appending data for item {item}")
            progress_var.set(progress_var.get() + 1)
    except Exception as e:
        print(f"Exception: {e}")
    finally:
        progress_var.set(progress_var.get() + 1)

progress_var = (0)

def start_threads():
    total_items = 1000000000
    num_threads = 100
    items_per_thread = total_items // num_threads
    threads = []
    for i in range(num_threads):
        start = i * items_per_thread + 1
        end = (i + 1) * items_per_thread if i < num_threads - 1 else total_items
        thread = threading.Thread(target=my_operation, args=(start, end, progress_var))
        threads.append(thread)
        thread.start()

    for thread in threads:
        thread.join()
        print(thread)
    print("All threads completed.")
    print("Total count:", total_count)

start_threads()
# Out:
# Exception in thread Thread-386 (my_operation):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1008.0_x64__qbz5n2kfra8p0\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\maxik\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ipykernel\ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1008.0_x64__qbz5n2kfra8p0\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\maxik\AppData\Local\Temp\ipykernel_25596\783692876.py", line 38, in my_operation
# AttributeError: 'int' object has no attribute 'set'
# Error appending data for item 830000001
# Exception: 'int' object has no attribute 'set'
# Exception in thread Thread-387 (my_operation):
# ...

# %%
import threading
import requests

# Global variable to keep track of the count
count_lock = threading.Lock()
total_count = 0

def append_to_file(data, file_path="fileROBLOXtokens.txt"):
    try:
        with open(file_path, "a") as file:
            file.write(f"{str(data)}" + "\n")
        print(f"Data appended to {file_path}")
    except Exception as e:
        print(f"Error appending data to {file_path}: {e}")

def is_valid_url(url):
    try:
        response = requests.head(url)
        return response.status_code == 200
    except requests.ConnectionError:
        return False

def my_operation(start, end, progress_var):
    global total_count
    try:
        for item in range(start, end + 1):
            url_to_check = f"https://www.roblox.com/games/{item}/Murder-Mystery-2"
            if is_valid_url(url_to_check):
                append_to_file(item)
                with count_lock:
                    total_count += 1
            else:
                print(f"Error appending data for item {item}")
            progress_var.set(progress_var.get() + 1)
    except Exception as e:
        print(f"Exception: {e}")
    finally:
        progress_var.set(progress_var.get() + 1)

progress_var = (0)

def start_threads():
    total_items = 1000000000
    num_threads = 100
    items_per_thread = total_items // num_threads
    threads = []
    for i in range(num_threads):
        start = i * items_per_thread + 1
        end = (i + 1) * items_per_thread if i < num_threads - 1 else total_items
        thread = threading.Thread(target=my_operation, args=(start, end, progress_var))
        threads.append(thread)
        thread.start()

    for thread in threads:
        thread.join()
        print(thread)
    print("All threads completed.")
    print("Total count:", int(str(total_count).replace('0', '1')))

start_threads()
# Out:
# Exception in thread Thread-426 (my_operation):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1008.0_x64__qbz5n2kfra8p0\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\maxik\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ipykernel\ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1008.0_x64__qbz5n2kfra8p0\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\maxik\AppData\Local\Temp\ipykernel_25596\2243346752.py", line 38, in my_operation
# AttributeError: 'int' object has no attribute 'set'
# Exception in thread Thread-497 (my_operation):
# Traceback (most recent call last):
# ...
